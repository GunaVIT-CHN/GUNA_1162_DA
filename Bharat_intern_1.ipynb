# %% [markdown]
# #Guna Shankar 20MIA1162 VIT CHN

# %% [markdown]
# #3) Handwritten digit recognition system not only detects
# scanned images of handwritten digits.Handwritten digit
# recognition using MNIST dataset is a major project made
#
# with the help of Neural Network. It basically detects
# the scanned images of handwritten digits.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np

# Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # Flatten 28x28 images to a 1D array
    tf.keras.layers.Dense(128, activation='relu'),    # Hidden layer with 128 units and ReLU activation
    tf.keras.layers.Dense(64, activation='relu'),     # Additional hidden layer with 64 units and ReLU activation
    tf.keras.layers.Dense(10, activation='softmax')   # Output layer with 10 units (one for each digit) and softmax activation
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=20, batch_size=64, validation_split=0.1)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print("Test accuracy:", test_accuracy)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 11s 4ms/step - loss: 0.2581 - accuracy: 0.9244 - val_loss: 0.1222 - val_accuracy: 0.9637
# Epoch 2/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1063 - accuracy: 0.9675 - val_loss: 0.0996 - val_accuracy: 0.9727
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0727 - accuracy: 0.9775 - val_loss: 0.0821 - val_accuracy: 0.9743
# Epoch 4/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0555 - accuracy: 0.9819 - val_loss: 0.0806 - val_accuracy: 0.9782
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0424 - accuracy: 0.9861 - val_loss: 0.1220 - val_accuracy: 0.9677
# Epoch 6/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0348 - accuracy: 0.9887 - val_loss: 0.0855 - val_accuracy: 0.9790
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # Flatten 28x28 images to a 1D array
    tf.keras.layers.Dense(128, activation='relu'),    # Hidden layer with 128 units and ReLU activation
    tf.keras.layers.Dense(64, activation='relu'),     # Additional hidden layer with 64 units and ReLU activation
    tf.keras.layers.Dense(10, activation='softmax')   # Output layer with 10 units (one for each digit) and softmax activation
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Define hyperparameters
epochs = 20
batch_size = 64
validation_split = 0.1

# Train the model and store the training history
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_split=validation_split)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print("Test accuracy:", test_accuracy)

# Plot the training loss and accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Display sample images from the MNIST dataset
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(train_images[i], cmap='gray')
    plt.title(f"Label: {train_labels[i]}")
    plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 844/844 [==============================] - 6s 4ms/step - loss: 0.2904 - accuracy: 0.9161 - val_loss: 0.1187 - val_accuracy: 0.9665
# Epoch 2/20
# 844/844 [==============================] - 3s 3ms/step - loss: 0.1222 - accuracy: 0.9635 - val_loss: 0.1049 - val_accuracy: 0.9700
# Epoch 3/20
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0830 - accuracy: 0.9750 - val_loss: 0.0843 - val_accuracy: 0.9748
# Epoch 4/20
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0602 - accuracy: 0.9811 - val_loss: 0.0893 - val_accuracy: 0.9747
# Epoch 5/20
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0480 - accuracy: 0.9846 - val_loss: 0.0802 - val_accuracy: 0.9767
# Epoch 6/20
# 844/844 [==============================] - 3s 3ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 0.0775 - val_accuracy: 0.9765
# Epoch 7/20
# ...

# %%
# Display sample images from the MNIST dataset
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(train_images[i], cmap='gray')
    plt.title(f"Label: {train_labels[i]}")
    plt.axis('off')
plt.show()

# Select a random image from the test dataset for prediction
random_index = np.random.randint(0, len(test_images))
random_image = test_images[random_index]

# Reshape the image to match the model's input shape (1 sample, 28x28 image)
random_image = np.expand_dims(random_image, axis=0)

# Predict the number using the model
predicted_label = model.predict(random_image)
predicted_number = np.argmax(predicted_label)

# Display the random image and its predicted label
plt.imshow(test_images[random_index], cmap='gray')
plt.title(f"Predicted Number: {predicted_number}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 79ms/step
